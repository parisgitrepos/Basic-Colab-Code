# %%
# Retrieve git_key from Google Drive file

KEY_FILE_NAME = "Git Key.txt" #@param {type:"string"}
with open('drive/MyDrive/Colab Notebooks/'+KEY_FILE_NAME) as file:
  git_key = file.readline()

# %%
# Clone git repo

REPO_NAME = "Basic Colab Code" #@param {type:"string"}
REPO_NAME = REPO_NAME.lower()
REPO_NAME = REPO_NAME.replace(' ', '-')
REPO_NAME += '.git'
# !cd drive; cd MyDrive; cd Colab\ Notebooks; git clone https://thepythoncoder2019:$git_key@bitbucket.org/thepythoncoder2019/$REPO_NAME
# Out:
# Cloning into 'basic-colab-code'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 10 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (10/10), done.

# %%
# Commit/push to BitBucket

REPO_NAME = "Basic Colab Code" #@param {type:"string"}
REPO_NAME = REPO_NAME.replace(' ', '-')
REPO_NAME = REPO_NAME.lower()
USER_EMAIL = "punaterparas@gmail.com" #@param {type:"string"}
USER_EMAIL = '"' + USER_EMAIL + '"'
COMMIT_MESSAGE = "Modifications to retrieving git_k" #@param {type:"string"}
COMMIT_MESSAGE = '"' + COMMIT_MESSAGE + '"'
# !cd drive; cd MyDrive; cd Colab\ Notebooks; cd $REPO_NAME; git config --global user.email $USER_EMAIL; git add .; git commit -m $COMMIT_MESSAGE; git push
# Out:
# [master 0e216d3] Modifications to commit/push code
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 856 bytes | 285.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0)
# To https://bitbucket.org/thepythoncoder2019/basic-colab-code.git
#    b1bb1df..0e216d3  master -> master

# %%
# Pull from BitBucket

REPO_NAME = "" #@param {type:"string"}
REPO_NAME = REPO_NAME.replace(' ', '-')
REPO_NAME = REPO_NAME.lower()
# !cd drive; cd MyDrive; cd Colab\ Notebooks; cd housing-prices-ml; git config --global user.email "punaterparas@gmail.com"; git config --global user.name "Paras (Colab)"; git pull
